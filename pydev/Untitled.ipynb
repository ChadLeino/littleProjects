# %%
class DewPointSensor:
    def __init__(self, name, minimumSafeDewpoint):
        self.name = name
        self.minimumSafeDewpointn = minimumSafeDewpoint
        self.readings = []

    def addReading(reading):
        self.readings.append(reading)

    def findAverage(
